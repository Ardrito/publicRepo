# %%
from PIL import Image
import scipy.misc
import numpy as np
import imageio.v2 as imageio
import matplotlib.pyplot as plt
import cv2

# %%
img = imageio.imread("three.jpg", mode='L')
#img = np.resize(img, (28,28))
img = (255.0-img)/255
print (img.shape)
# Out:
# KeyboardInterrupt

# %%
plt.imshow(img, cmap=plt.cm.binary)

# %%
print (img)
# Out:
# [[0.20392157 0.3372549  0.3372549  ... 0.25882353 0.2627451  0.2627451 ]
#  [0.20392157 0.3372549  0.3372549  ... 0.25882353 0.2627451  0.2627451 ]
#  [0.2        0.33333333 0.33333333 ... 0.25882353 0.2627451  0.2627451 ]
#  ...
#  [0.42745098 0.30196078 0.34117647 ... 0.40392157 0.40784314 0.41176471]
#  [0.45098039 0.31372549 0.34509804 ... 0.40784314 0.41176471 0.41960784]
#  [0.4627451  0.31764706 0.34901961 ... 0.40784314 0.41568627 0.42352941]]

# %%
img2 = cv2.imread("three.jpg",cv2.IMREAD_GRAYSCALE) #Read the image as a grayscale
resized = cv2.resize(img2, (28,28))

plt.imshow(img2, cmap='grey')

# %%
img2 = cv2.resize(img2,(28,28), interpolation=cv2.INTER_CUBIC)

plt.imshow(img2, cmap='grey')
